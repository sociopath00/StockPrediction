# %%
# import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from config import DATA_COLUMNS

# %%
# load the dataset
df = pd.read_csv("RIL_equity_3_years.csv")
print("The dataset has {} rows and {} columns".format(*df.shape))
# Out:
# The dataset has 492 rows and 13 columns

# %%
# display 1st 5 rows of our data
df.head()
# Out:
#              Date  Open Price  High Price  Low Price  Close Price  \
# 0  25-August-2020     2105.00     2111.30    2078.30      2082.00
# 1  24-August-2020     2098.80     2104.65    2070.15      2096.05
# 2  21-August-2020     2119.80     2119.80    2077.05      2081.75
# 3  20-August-2020     2118.05     2123.90    2087.80      2096.35
# 4  19-August-2020     2141.95     2154.00    2121.35      2133.20
#
#            WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  2089.298804        481884          26648          1.006800e+09
# 1  2088.306518        560786          22213          1.171093e+09
# 2  2096.925519        437199          19487          9.167737e+08
# 3  2108.788895        494200          30536          1.042163e+09
# 4  2139.151365        758768          36447          1.623120e+09
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                144101                      29.90            33.00
# ...

# %%
# # display last 5 rows of our data
df.tail()
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 487  31-August-2018     1273.80     1273.80    1237.05      1240.95
# 488  30-August-2018     1300.00     1300.00    1270.45      1274.10
# 489  29-August-2018     1319.00     1328.75    1290.30      1294.45
# 490  28-August-2018     1298.75     1323.00    1295.50      1318.20
# 491  27-August-2018     1280.05     1296.20    1280.00      1291.60
#
#              WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 487  1251.350399       1284024          14772          1.606764e+09
# 488  1278.056380       1802595          11065          2.303818e+09
# 489  1309.211052        570571          15437          7.469979e+08
# 490  1310.944019        484736          12158          6.354618e+08
# 491  1290.466958        288953           7343          3.728843e+08
#
#      Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 487                900813                      70.16            36.75
# ...

# %% [markdown]
# - We have data from 27th August,2018 to 25th August,2020
#
#
# - *Spread High-Low* and *Spread Close-Open* are derived columns that represent difference between High-Low and Open-Close values respectivly for that day
